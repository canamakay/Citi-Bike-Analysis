# %% [markdown]
# # Data Cleaning and Consistency Checks

# %% [markdown]
# ## Table of Contents
# ### 01. Importing Libraries and Data
# ### 02. Data Cleaning and Consistency Checks
# #### Missing Values
# #### Duplicates
# #### Mixed-type Data
# #### Renaming Columns
# #### Checking Data Types
# ### 03. Descriptive Statistics
# ### 04. Adding New Variables
# ### 05. Dropping Columns

# %% [markdown]
# ## 01. Importing Libraries and Data

# %%
#importing libaries
import pandas as pd
import numpy as np
import os

# %%
#importing data
#Creating path:
path = r'C:\Users\canam\Achievement 6\Citibike Analysis'

# %%
#importing data
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'citibike.csv'), index_col = False)

# %%
#checking shape of the data
df.shape
# Out:
# (50000, 18)

# %% [markdown]
# ## Data Cleaning and Consistency Checks

# %% [markdown]
# ### Missing Values

# %%
#finding missing values
df.isnull().sum()
# Out:
# trip_id                       0
# bike_id                       0
# weekday                       0
# start_hour                    0
# start_time                    0
# start_station_id              0
# start_station_name            0
# start_station_latitude        0
# start_station_longitude       0
# end_time                      0
# end_station_id                0
# end_station_name              0
# end_station_latitude          0
# end_station_longitude         0
# trip_duration                 0
# subscriber                    0
# birth_year                 6979
# gender                        0
# dtype: int64

# %%
#There are 6979 rows with birth year missing.  Removing these would mean removing more than 5% of data so I will use mean imputation.

# %%
#imputing missing birth_year values with mean
df['birth_year_mean'] = df['birth_year'].fillna(df['birth_year'].mean())

# %%
#checking to see that missing values were imputed 
df.isnull().sum()
# Out:
# trip_id                       0
# bike_id                       0
# weekday                       0
# start_hour                    0
# start_time                    0
# start_station_id              0
# start_station_name            0
# start_station_latitude        0
# start_station_longitude       0
# end_time                      0
# end_station_id                0
# end_station_name              0
# end_station_latitude          0
# end_station_longitude         0
# trip_duration                 0
# subscriber                    0
# birth_year                 6979
# gender                        0
# birth_year_mean               0
# dtype: int64

# %%
#checking new column birth_year_mean
df.head(5)
# Out:
#   trip_id  bike_id weekday  start_hour           start_time  start_station_id  \
# 0  LnQzQk    16013     Mon          18  2013-09-09 18:18:55               523
# 1  IL9boN    15230     Thu          18  2013-09-12 18:38:53               257
# 2  46clGB    17942     Wed          19  2013-09-18 19:44:04               479
# 3  v7vdFt    19683     Sat          11  2013-09-28 11:54:37               527
# 4  VGBsb5    18024     Sat          18  2013-09-07 18:08:22               521
#
#         start_station_name  start_station_latitude  start_station_longitude  \
# 0          W 38 St & 8 Ave               40.754666               -73.991382
# 1  Lispenard St & Broadway               40.719392               -74.002472
# 2          9 Ave & W 45 St               40.760193               -73.991255
# 3          E 33 St & 1 Ave               40.743156               -73.974347
# 4          8 Ave & W 31 St               40.750450               -73.994811
#
#               end_time  end_station_id     end_station_name  \
# 0  2013-09-09 18:35:28             334      W 20 St & 7 Ave
# 1  2013-09-12 18:48:34             236  St Marks Pl & 2 Ave
# 2  2013-09-18 19:50:05             513     W 56 St & 10 Ave
# 3  2013-09-28 12:03:58             441      E 52 St & 2 Ave
# 4  2013-09-07 18:46:38             476      E 31 St & 3 Ave
#
#    end_station_latitude  end_station_longitude  trip_duration      subscriber  \
# 0             40.742388             -73.997262            993      Subscriber
# 1             40.728419             -73.987140            581      Subscriber
# 2             40.768254             -73.988639            361      Subscriber
# 3             40.756014             -73.967416            561      Subscriber
# 4             40.743943             -73.979661           2296  Non-Subscriber
#
#    birth_year  gender  birth_year_mean
# 0      1968.0       2      1968.000000
# 1      1983.0       1      1983.000000
# 2      1989.0       1      1989.000000
# 3      1988.0       2      1988.000000
# 4         NaN       0      1975.627786

# %%
#getting rid of the birth_year column with missing values

# %%
df=df.drop(columns = ['birth_year'])

# %%
#checking to see if birth_year column has been dropped
df.head(5)
# Out:
#   trip_id  bike_id weekday  start_hour           start_time  start_station_id  \
# 0  LnQzQk    16013     Mon          18  2013-09-09 18:18:55               523
# 1  IL9boN    15230     Thu          18  2013-09-12 18:38:53               257
# 2  46clGB    17942     Wed          19  2013-09-18 19:44:04               479
# 3  v7vdFt    19683     Sat          11  2013-09-28 11:54:37               527
# 4  VGBsb5    18024     Sat          18  2013-09-07 18:08:22               521
#
#         start_station_name  start_station_latitude  start_station_longitude  \
# 0          W 38 St & 8 Ave               40.754666               -73.991382
# 1  Lispenard St & Broadway               40.719392               -74.002472
# 2          9 Ave & W 45 St               40.760193               -73.991255
# 3          E 33 St & 1 Ave               40.743156               -73.974347
# 4          8 Ave & W 31 St               40.750450               -73.994811
#
#               end_time  end_station_id     end_station_name  \
# 0  2013-09-09 18:35:28             334      W 20 St & 7 Ave
# 1  2013-09-12 18:48:34             236  St Marks Pl & 2 Ave
# 2  2013-09-18 19:50:05             513     W 56 St & 10 Ave
# 3  2013-09-28 12:03:58             441      E 52 St & 2 Ave
# 4  2013-09-07 18:46:38             476      E 31 St & 3 Ave
#
#    end_station_latitude  end_station_longitude  trip_duration      subscriber  \
# 0             40.742388             -73.997262            993      Subscriber
# 1             40.728419             -73.987140            581      Subscriber
# 2             40.768254             -73.988639            361      Subscriber
# 3             40.756014             -73.967416            561      Subscriber
# 4             40.743943             -73.979661           2296  Non-Subscriber
#
#    gender  birth_year_mean
# 0       2      1968.000000
# 1       1      1983.000000
# 2       1      1989.000000
# 3       2      1988.000000
# 4       0      1975.627786

# %%
#renaming birth_year_mean to birth_year
df.rename(columns = {'birth_year_mean' : 'birth_year'}, inplace = True)

# %%
#cheking to see that the column was renamed
df.head()
# Out:
#   trip_id  bike_id weekday  start_hour           start_time  start_station_id  \
# 0  LnQzQk    16013     Mon          18  2013-09-09 18:18:55               523
# 1  IL9boN    15230     Thu          18  2013-09-12 18:38:53               257
# 2  46clGB    17942     Wed          19  2013-09-18 19:44:04               479
# 3  v7vdFt    19683     Sat          11  2013-09-28 11:54:37               527
# 4  VGBsb5    18024     Sat          18  2013-09-07 18:08:22               521
#
#         start_station_name  start_station_latitude  start_station_longitude  \
# 0          W 38 St & 8 Ave               40.754666               -73.991382
# 1  Lispenard St & Broadway               40.719392               -74.002472
# 2          9 Ave & W 45 St               40.760193               -73.991255
# 3          E 33 St & 1 Ave               40.743156               -73.974347
# 4          8 Ave & W 31 St               40.750450               -73.994811
#
#               end_time  end_station_id     end_station_name  \
# 0  2013-09-09 18:35:28             334      W 20 St & 7 Ave
# 1  2013-09-12 18:48:34             236  St Marks Pl & 2 Ave
# 2  2013-09-18 19:50:05             513     W 56 St & 10 Ave
# 3  2013-09-28 12:03:58             441      E 52 St & 2 Ave
# 4  2013-09-07 18:46:38             476      E 31 St & 3 Ave
#
#    end_station_latitude  end_station_longitude  trip_duration      subscriber  \
# 0             40.742388             -73.997262            993      Subscriber
# 1             40.728419             -73.987140            581      Subscriber
# 2             40.768254             -73.988639            361      Subscriber
# 3             40.756014             -73.967416            561      Subscriber
# 4             40.743943             -73.979661           2296  Non-Subscriber
#
#    gender   birth_year
# 0       2  1968.000000
# 1       1  1983.000000
# 2       1  1989.000000
# 3       2  1988.000000
# 4       0  1975.627786

# %% [markdown]
# ### Duplicates

# %%
#looking for duplicates
df_dups = df[df.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [trip_id, bike_id, weekday, start_hour, start_time, start_station_id, start_station_name, start_station_latitude, start_station_longitude, end_time, end_station_id, end_station_name, end_station_latitude, end_station_longitude, trip_duration, subscriber, gender, birth_year]
# Index: []

# %%
##there are no duplicates

# %% [markdown]
# ### Mixed-type data

# %%
##checking for mixed-type data
for col in df.columns.tolist():
  weird = (df[[col]].map(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)

# %%
##there are no columns with mixed data

# %% [markdown]
# ### Renaming Columns

# %%
#checking columns for things that need to be renamed 
df.head(5)
# Out:
#   trip_id  bike_id weekday  start_hour           start_time  start_station_id  \
# 0  LnQzQk    16013     Mon          18  2013-09-09 18:18:55               523
# 1  IL9boN    15230     Thu          18  2013-09-12 18:38:53               257
# 2  46clGB    17942     Wed          19  2013-09-18 19:44:04               479
# 3  v7vdFt    19683     Sat          11  2013-09-28 11:54:37               527
# 4  VGBsb5    18024     Sat          18  2013-09-07 18:08:22               521
#
#         start_station_name  start_station_latitude  start_station_longitude  \
# 0          W 38 St & 8 Ave               40.754666               -73.991382
# 1  Lispenard St & Broadway               40.719392               -74.002472
# 2          9 Ave & W 45 St               40.760193               -73.991255
# 3          E 33 St & 1 Ave               40.743156               -73.974347
# 4          8 Ave & W 31 St               40.750450               -73.994811
#
#               end_time  end_station_id     end_station_name  \
# 0  2013-09-09 18:35:28             334      W 20 St & 7 Ave
# 1  2013-09-12 18:48:34             236  St Marks Pl & 2 Ave
# 2  2013-09-18 19:50:05             513     W 56 St & 10 Ave
# 3  2013-09-28 12:03:58             441      E 52 St & 2 Ave
# 4  2013-09-07 18:46:38             476      E 31 St & 3 Ave
#
#    end_station_latitude  end_station_longitude  trip_duration      subscriber  \
# 0             40.742388             -73.997262            993      Subscriber
# 1             40.728419             -73.987140            581      Subscriber
# 2             40.768254             -73.988639            361      Subscriber
# 3             40.756014             -73.967416            561      Subscriber
# 4             40.743943             -73.979661           2296  Non-Subscriber
#
#    gender   birth_year
# 0       2  1968.000000
# 1       1  1983.000000
# 2       1  1989.000000
# 3       2  1988.000000
# 4       0  1975.627786

# %%
#changing weekday to day_of_week
df.rename(columns = {'weekday' : 'day_of_week'}, inplace = True)

# %%
#checking to see if it has been changed
df.head()
# Out:
#   trip_id  bike_id day_of_week  start_hour           start_time  \
# 0  LnQzQk    16013         Mon          18  2013-09-09 18:18:55
# 1  IL9boN    15230         Thu          18  2013-09-12 18:38:53
# 2  46clGB    17942         Wed          19  2013-09-18 19:44:04
# 3  v7vdFt    19683         Sat          11  2013-09-28 11:54:37
# 4  VGBsb5    18024         Sat          18  2013-09-07 18:08:22
#
#    start_station_id       start_station_name  start_station_latitude  \
# 0               523          W 38 St & 8 Ave               40.754666
# 1               257  Lispenard St & Broadway               40.719392
# 2               479          9 Ave & W 45 St               40.760193
# 3               527          E 33 St & 1 Ave               40.743156
# 4               521          8 Ave & W 31 St               40.750450
#
#    start_station_longitude             end_time  end_station_id  \
# 0               -73.991382  2013-09-09 18:35:28             334
# 1               -74.002472  2013-09-12 18:48:34             236
# 2               -73.991255  2013-09-18 19:50:05             513
# 3               -73.974347  2013-09-28 12:03:58             441
# 4               -73.994811  2013-09-07 18:46:38             476
#
#       end_station_name  end_station_latitude  end_station_longitude  \
# 0      W 20 St & 7 Ave             40.742388             -73.997262
# 1  St Marks Pl & 2 Ave             40.728419             -73.987140
# 2     W 56 St & 10 Ave             40.768254             -73.988639
# 3      E 52 St & 2 Ave             40.756014             -73.967416
# 4      E 31 St & 3 Ave             40.743943             -73.979661
#
#    trip_duration      subscriber  gender   birth_year
# 0            993      Subscriber       2  1968.000000
# 1            581      Subscriber       1  1983.000000
# 2            361      Subscriber       1  1989.000000
# 3            561      Subscriber       2  1988.000000
# 4           2296  Non-Subscriber       0  1975.627786

# %% [markdown]
# ### Checking Data Types

# %%
df.dtypes
# Out:
# trip_id                     object
# bike_id                      int64
# day_of_week                 object
# start_hour                   int64
# start_time                  object
# start_station_id             int64
# start_station_name          object
# start_station_latitude     float64
# start_station_longitude    float64
# end_time                    object
# end_station_id               int64
# end_station_name            object
# end_station_latitude       float64
# end_station_longitude      float64
# trip_duration                int64
# subscriber                  object
# gender                       int64
# birth_year                 float64
# dtype: object

# %%
#Need to make the following changes:
#bike_id to string
#start_time into datetime
#start_station_id into string
#end_time into datetime
#end_station_id into string
#gender into string

# %%
#converting bike_id into string
df['bike_id'] = df['bike_id'].astype('str')

# %%
#converting start_time into datetime 
df['start_time'] = pd.to_datetime(df['start_time'])

# %%
#converting start_station_id into string
df['start_station_id'] = df['start_station_id'].astype('str')

# %%
#converting end_time to datetime
df['end_time'] = pd.to_datetime(df['end_time'])

# %%
#converting end_station_id into string
df['end_station_id'] = df['end_station_id'].astype('str')

# %%
#converting gender into string
df['gender'] = df['gender'].astype('str')

# %%
#checking to see that data types were changed 
df.dtypes
# Out:
# trip_id                            object
# bike_id                            object
# day_of_week                        object
# start_hour                          int64
# start_time                 datetime64[ns]
# start_station_id                   object
# start_station_name                 object
# start_station_latitude            float64
# start_station_longitude           float64
# end_time                   datetime64[ns]
# end_station_id                     object
# end_station_name                   object
# end_station_latitude              float64
# end_station_longitude             float64
# trip_duration                       int64
# subscriber                         object
# gender                             object
# birth_year                        float64
# dtype: object

# %% [markdown]
# ### Descriptive Statistics

# %%
#gathering descriptive statistics
df.describe()
# Out:
#          start_hour                     start_time  start_station_latitude  \
# count  50000.000000                          50000            50000.000000
# mean      14.145240     2013-09-16 14:31:33.819680               40.734170
# min        0.000000            2013-09-01 00:00:35               40.680342
# 25%       10.000000  2013-09-09 10:25:46.750000128               40.720196
# 50%       15.000000     2013-09-16 18:54:12.500000               40.735877
# 75%       18.000000  2013-09-23 21:56:02.750000128               40.750020
# max       23.000000            2013-09-30 23:58:17               40.770513
# std        4.860541                            NaN                0.019911
#
#        start_station_longitude                       end_time  \
# count             50000.000000                          50000
# mean                -73.991109  2013-09-16 14:46:46.003320064
# min                 -74.017134            2013-09-01 00:07:15
# 25%                 -74.000271  2013-09-09 10:40:52.249999872
# 50%                 -73.990765            2013-09-16 19:11:10
# 75%                 -73.981923            2013-09-23 22:06:59
# max                 -73.950048            2013-10-01 00:15:29
# std                   0.012555                            NaN
#
#        end_station_latitude  end_station_longitude  trip_duration  \
# count          50000.000000           50000.000000   50000.000000
# mean              40.733859             -73.991351     838.982900
# min               40.680342             -74.017134      60.000000
# 25%               40.720196             -74.001547     417.000000
# 50%               40.735354             -73.991218     672.000000
# 75%               40.749013             -73.982050    1112.000000
# max               40.770513             -73.950048    2697.000000
# std                0.019885               0.012569     573.663997
#
#          birth_year
# count  50000.000000
# mean    1975.627786
# min     1899.000000
# 25%     1970.000000
# 50%     1975.627786
# 75%     1983.000000
# max     1997.000000
# std       10.286010

# %%
#the minimum birth year is 1899, which is highly unlikely.

# %%
#imputing mean where birth_year < 1913 (making the cutoff age 100 and the data is from 2013) 
df.loc[df['birth_year'] < 1913, 'birth_year'] = 1975.627786

# %%
#checking descriptive statistics again
df.describe()
# Out:
#          start_hour                     start_time  start_station_latitude  \
# count  50000.000000                          50000            50000.000000
# mean      14.145240     2013-09-16 14:31:33.819680               40.734170
# min        0.000000            2013-09-01 00:00:35               40.680342
# 25%       10.000000  2013-09-09 10:25:46.750000128               40.720196
# 50%       15.000000     2013-09-16 18:54:12.500000               40.735877
# 75%       18.000000  2013-09-23 21:56:02.750000128               40.750020
# max       23.000000            2013-09-30 23:58:17               40.770513
# std        4.860541                            NaN                0.019911
#
#        start_station_longitude                       end_time  \
# count             50000.000000                          50000
# mean                -73.991109  2013-09-16 14:46:46.003320064
# min                 -74.017134            2013-09-01 00:07:15
# 25%                 -74.000271  2013-09-09 10:40:52.249999872
# 50%                 -73.990765            2013-09-16 19:11:10
# 75%                 -73.981923            2013-09-23 22:06:59
# max                 -73.950048            2013-10-01 00:15:29
# std                   0.012555                            NaN
#
#        end_station_latitude  end_station_longitude  trip_duration  \
# count          50000.000000           50000.000000   50000.000000
# mean              40.733859             -73.991351     838.982900
# min               40.680342             -74.017134      60.000000
# 25%               40.720196             -74.001547     417.000000
# 50%               40.735354             -73.991218     672.000000
# 75%               40.749013             -73.982050    1112.000000
# max               40.770513             -73.950048    2697.000000
# std                0.019885               0.012569     573.663997
#
#          birth_year
# count  50000.000000
# mean    1975.662435
# min     1917.000000
# 25%     1970.000000
# 50%     1975.627786
# 75%     1983.000000
# max     1997.000000
# std       10.158183

# %%
#now the minimum birth_year is 1917

# %%
df.head()
# Out:
#   trip_id bike_id day_of_week  start_hour          start_time  \
# 0  LnQzQk   16013         Mon          18 2013-09-09 18:18:55
# 1  IL9boN   15230         Thu          18 2013-09-12 18:38:53
# 2  46clGB   17942         Wed          19 2013-09-18 19:44:04
# 3  v7vdFt   19683         Sat          11 2013-09-28 11:54:37
# 4  VGBsb5   18024         Sat          18 2013-09-07 18:08:22
#
#   start_station_id       start_station_name  start_station_latitude  \
# 0              523          W 38 St & 8 Ave               40.754666
# 1              257  Lispenard St & Broadway               40.719392
# 2              479          9 Ave & W 45 St               40.760193
# 3              527          E 33 St & 1 Ave               40.743156
# 4              521          8 Ave & W 31 St               40.750450
#
#    start_station_longitude            end_time end_station_id  \
# 0               -73.991382 2013-09-09 18:35:28            334
# 1               -74.002472 2013-09-12 18:48:34            236
# 2               -73.991255 2013-09-18 19:50:05            513
# 3               -73.974347 2013-09-28 12:03:58            441
# 4               -73.994811 2013-09-07 18:46:38            476
#
#       end_station_name  end_station_latitude  end_station_longitude  \
# 0      W 20 St & 7 Ave             40.742388             -73.997262
# 1  St Marks Pl & 2 Ave             40.728419             -73.987140
# 2     W 56 St & 10 Ave             40.768254             -73.988639
# 3      E 52 St & 2 Ave             40.756014             -73.967416
# 4      E 31 St & 3 Ave             40.743943             -73.979661
#
#    trip_duration      subscriber gender   birth_year
# 0            993      Subscriber      2  1968.000000
# 1            581      Subscriber      1  1983.000000
# 2            361      Subscriber      1  1989.000000
# 3            561      Subscriber      2  1988.000000
# 4           2296  Non-Subscriber      0  1975.627786

# %% [markdown]
# ### Creating new variables

# %%
#creating an age variable
df['Age']= 2013 - df['birth_year']

# %%
#checking to see if it was added
df.head()
# Out:
#   trip_id bike_id day_of_week  start_hour          start_time  \
# 0  LnQzQk   16013         Mon          18 2013-09-09 18:18:55
# 1  IL9boN   15230         Thu          18 2013-09-12 18:38:53
# 2  46clGB   17942         Wed          19 2013-09-18 19:44:04
# 3  v7vdFt   19683         Sat          11 2013-09-28 11:54:37
# 4  VGBsb5   18024         Sat          18 2013-09-07 18:08:22
#
#   start_station_id       start_station_name  start_station_latitude  \
# 0              523          W 38 St & 8 Ave               40.754666
# 1              257  Lispenard St & Broadway               40.719392
# 2              479          9 Ave & W 45 St               40.760193
# 3              527          E 33 St & 1 Ave               40.743156
# 4              521          8 Ave & W 31 St               40.750450
#
#    start_station_longitude            end_time end_station_id  \
# 0               -73.991382 2013-09-09 18:35:28            334
# 1               -74.002472 2013-09-12 18:48:34            236
# 2               -73.991255 2013-09-18 19:50:05            513
# 3               -73.974347 2013-09-28 12:03:58            441
# 4               -73.994811 2013-09-07 18:46:38            476
#
#       end_station_name  end_station_latitude  end_station_longitude  \
# 0      W 20 St & 7 Ave             40.742388             -73.997262
# 1  St Marks Pl & 2 Ave             40.728419             -73.987140
# 2     W 56 St & 10 Ave             40.768254             -73.988639
# 3      E 52 St & 2 Ave             40.756014             -73.967416
# 4      E 31 St & 3 Ave             40.743943             -73.979661
#
#    trip_duration      subscriber gender   birth_year        Age
# 0            993      Subscriber      2  1968.000000  45.000000
# 1            581      Subscriber      1  1983.000000  30.000000
# 2            361      Subscriber      1  1989.000000  24.000000
# 3            561      Subscriber      2  1988.000000  25.000000
# 4           2296  Non-Subscriber      0  1975.627786  37.372214

# %%
#renaming Age column to be consistent with others 
df.rename(columns = {'Age' : 'age'}, inplace = True)

# %%
#checking to see that it was renamed
df.head()
# Out:
#   trip_id bike_id day_of_week  start_hour          start_time  \
# 0  LnQzQk   16013         Mon          18 2013-09-09 18:18:55
# 1  IL9boN   15230         Thu          18 2013-09-12 18:38:53
# 2  46clGB   17942         Wed          19 2013-09-18 19:44:04
# 3  v7vdFt   19683         Sat          11 2013-09-28 11:54:37
# 4  VGBsb5   18024         Sat          18 2013-09-07 18:08:22
#
#   start_station_id       start_station_name  start_station_latitude  \
# 0              523          W 38 St & 8 Ave               40.754666
# 1              257  Lispenard St & Broadway               40.719392
# 2              479          9 Ave & W 45 St               40.760193
# 3              527          E 33 St & 1 Ave               40.743156
# 4              521          8 Ave & W 31 St               40.750450
#
#    start_station_longitude            end_time end_station_id  \
# 0               -73.991382 2013-09-09 18:35:28            334
# 1               -74.002472 2013-09-12 18:48:34            236
# 2               -73.991255 2013-09-18 19:50:05            513
# 3               -73.974347 2013-09-28 12:03:58            441
# 4               -73.994811 2013-09-07 18:46:38            476
#
#       end_station_name  end_station_latitude  end_station_longitude  \
# 0      W 20 St & 7 Ave             40.742388             -73.997262
# 1  St Marks Pl & 2 Ave             40.728419             -73.987140
# 2     W 56 St & 10 Ave             40.768254             -73.988639
# 3      E 52 St & 2 Ave             40.756014             -73.967416
# 4      E 31 St & 3 Ave             40.743943             -73.979661
#
#    trip_duration      subscriber gender   birth_year        age
# 0            993      Subscriber      2  1968.000000  45.000000
# 1            581      Subscriber      1  1983.000000  30.000000
# 2            361      Subscriber      1  1989.000000  24.000000
# 3            561      Subscriber      2  1988.000000  25.000000
# 4           2296  Non-Subscriber      0  1975.627786  37.372214

# %%
#creating a column for trip duration in minutes
df['trip_duration_mins']= df['trip_duration']/60

# %%
#checking to see if trip_duration_mins was added
df.head()
# Out:
#   trip_id bike_id day_of_week  start_hour          start_time  \
# 0  LnQzQk   16013         Mon          18 2013-09-09 18:18:55
# 1  IL9boN   15230         Thu          18 2013-09-12 18:38:53
# 2  46clGB   17942         Wed          19 2013-09-18 19:44:04
# 3  v7vdFt   19683         Sat          11 2013-09-28 11:54:37
# 4  VGBsb5   18024         Sat          18 2013-09-07 18:08:22
#
#   start_station_id       start_station_name  start_station_latitude  \
# 0              523          W 38 St & 8 Ave               40.754666
# 1              257  Lispenard St & Broadway               40.719392
# 2              479          9 Ave & W 45 St               40.760193
# 3              527          E 33 St & 1 Ave               40.743156
# 4              521          8 Ave & W 31 St               40.750450
#
#    start_station_longitude            end_time end_station_id  \
# 0               -73.991382 2013-09-09 18:35:28            334
# 1               -74.002472 2013-09-12 18:48:34            236
# 2               -73.991255 2013-09-18 19:50:05            513
# 3               -73.974347 2013-09-28 12:03:58            441
# 4               -73.994811 2013-09-07 18:46:38            476
#
#       end_station_name  end_station_latitude  end_station_longitude  \
# 0      W 20 St & 7 Ave             40.742388             -73.997262
# 1  St Marks Pl & 2 Ave             40.728419             -73.987140
# 2     W 56 St & 10 Ave             40.768254             -73.988639
# 3      E 52 St & 2 Ave             40.756014             -73.967416
# 4      E 31 St & 3 Ave             40.743943             -73.979661
#
#    trip_duration      subscriber gender   birth_year        age  \
# 0            993      Subscriber      2  1968.000000  45.000000
# 1            581      Subscriber      1  1983.000000  30.000000
# 2            361      Subscriber      1  1989.000000  24.000000
# 3            561      Subscriber      2  1988.000000  25.000000
# 4           2296  Non-Subscriber      0  1975.627786  37.372214
#
#    trip_duration_mins
# 0           16.550000
# 1            9.683333
# 2            6.016667
# 3            9.350000
# 4           38.266667

# %% [markdown]
#  ### Dropping Columns

# %%
#dropping columns that are not needed in our analysis
df = df.drop(['trip_id', 'bike_id', 'trip_duration', 'birth_year'], axis=1)

# %%
#checking to see that columns have been dropped
df.head()
# Out:
#   day_of_week  start_hour          start_time start_station_id  \
# 0         Mon          18 2013-09-09 18:18:55              523
# 1         Thu          18 2013-09-12 18:38:53              257
# 2         Wed          19 2013-09-18 19:44:04              479
# 3         Sat          11 2013-09-28 11:54:37              527
# 4         Sat          18 2013-09-07 18:08:22              521
#
#         start_station_name  start_station_latitude  start_station_longitude  \
# 0          W 38 St & 8 Ave               40.754666               -73.991382
# 1  Lispenard St & Broadway               40.719392               -74.002472
# 2          9 Ave & W 45 St               40.760193               -73.991255
# 3          E 33 St & 1 Ave               40.743156               -73.974347
# 4          8 Ave & W 31 St               40.750450               -73.994811
#
#              end_time end_station_id     end_station_name  \
# 0 2013-09-09 18:35:28            334      W 20 St & 7 Ave
# 1 2013-09-12 18:48:34            236  St Marks Pl & 2 Ave
# 2 2013-09-18 19:50:05            513     W 56 St & 10 Ave
# 3 2013-09-28 12:03:58            441      E 52 St & 2 Ave
# 4 2013-09-07 18:46:38            476      E 31 St & 3 Ave
#
#    end_station_latitude  end_station_longitude      subscriber gender  \
# 0             40.742388             -73.997262      Subscriber      2
# 1             40.728419             -73.987140      Subscriber      1
# 2             40.768254             -73.988639      Subscriber      1
# 3             40.756014             -73.967416      Subscriber      2
# 4             40.743943             -73.979661  Non-Subscriber      0
#
#          age  trip_duration_mins
# 0  45.000000           16.550000
# 1  30.000000            9.683333
# 2  24.000000            6.016667
# 3  25.000000            9.350000
# 4  37.372214           38.266667

# %%
df.to_csv(os.path.join(path, '02 Data','Prepared Data', 'citibike_cleaned.csv'))
